# %% [markdown]
# <a href="https://colab.research.google.com/github/241b319-KESHAV/KESHAV/blob/main/lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
import heapq

def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    distances[start] = 0
    pq = [(0, start)]
    while pq:
        current_distance, current_node = heapq.heappop(pq)

        for neighbor, weight in graph[current_node].items():
            new_distance = current_distance + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = current_node
                heapq.heappush(pq, (new_distance, neighbor))
    return distances, previous
def shortest_path(previous, start, target):
    path = []
    node = target
    while node is not None:
        path.insert(0, node)
        node = previous[node]
    if path[0] == start:
        return path
    else:
        return None
graph = {}
n = int(input("Enter number of nodes: "))
for i in range(n):
    node = input(f"Enter node {i+1} name: ")
    graph[node] = {}
    edges = int(input(f"Enter number of edges from {node}: "))
    for j in range(edges):
        neighbor = input(f"  Enter neighbor {j+1} of {node}: ")
        weight = int(input(f"  Enter weight to {neighbor}: "))
        graph[node][neighbor] = weight
graph["X"] = {"Y": 4}
graph["Y"] = {"X": 4}
while True:
    start = input("\nEnter source node (or 'exit' to quit): ")
    if start == "exit":
        break
    distances, previous = dijkstra(graph, start)
    for target in graph:
        if target == start:
            continue
        path = shortest_path(previous, start, target)
        if path:
            print(f"Shortest path from {start} to {target}: {path} with distance {distances[target]}")
        else:
            print(f"No path from {start} to {target}")
# Out:
# Enter number of nodes: 9
# Enter node 1 name: C
# Enter number of edges from C: 2
#   Enter neighbor 1 of C: K
#   Enter weight to K: 5
#   Enter neighbor 2 of C: O
#   Enter weight to O: 6
# Enter node 2 name: P
# Enter number of edges from P: 2
#   Enter neighbor 1 of P: I
#   Enter weight to I: 4
#   Enter neighbor 2 of P: U
#   Enter weight to U: 7
# Enter node 3 name: W
# Enter number of edges from W: 3
#   Enter neighbor 1 of W: Z
#   Enter weight to Z: 3
#   Enter neighbor 2 of W: 8
#   Enter weight to 8: 5
#   Enter neighbor 3 of W: M
#   Enter weight to M: 7
# Enter node 4 name: V
# Enter number of edges from V: 1
#   Enter neighbor 1 of V: E
#   Enter weight to E: 1
# Enter node 5 name: R
# Enter number of edges from R: 2
#   Enter neighbor 1 of R: B
#   Enter weight to B: 4
#   Enter neighbor 2 of R: A
#   Enter weight to A: 2
# Enter node 6 name: exit
# Enter number of edges from exit: 1
#   Enter neighbor 1 of exit: l
#   Enter weight to l: 5
# Enter node 7 name: exit
